# %% [markdown]
# <a href="https://colab.research.google.com/github/ChetanGirave08/Data-Analysis-Project/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()

# %%
import numpy as np
import pandas as pd

df = pd.read_csv('train.csv')

# %%
# car - red, yellow, orange 26k 40k 50k

# car. red yellow orange   cost
# car.  1.    0.    0.      26k
# car.  0.    1.    0.      40k
# car.  0.    0.    1.      50k

# %%
# more aprroed or rejected?
# # bar chart of loan status
# # box plot for loan amount
# # which group has highter loan approval
# # which feature looks important for loan approval  hthv
